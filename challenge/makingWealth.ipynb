# %%
import sys
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\wmata\OneDrive\Documents\University\Year2\IML\IML.HUJI\challenge\wealthy_countries.csv")
d = dict()
df
# Out:
#                      Location   Median
# 0                  Luxembourg  259,899
# 1                   Australia  238,072
# 2                     Iceland  231,462
# 3                     Belgium  230,548
# 4                   Hong Kong  173,768
# ..                        ...      ...
# 163                Mozambique      345
# 164                   Burundi      281
# 165                   Lesotho      264
# 166  Central African Republic      212
# 167                     Haiti      193
#
# [168 rows x 2 columns]

# %%
df.Location
df["Median"] = df["Median"].str.replace(",","")

# %%
df["Median"]
# Out:
# 0      259899
# 1      238072
# 2      231462
# 3      230548
# 4      173768
#         ...
# 163       345
# 164       281
# 165       264
# 166       212
# 167       193
# Name: Median, Length: 168, dtype: object

# %%
df["Median"] = df["Median"].astype(np.float)
# Out:
# C:\Users\wmata\anaconda3\envs\iml.env\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
for i in range(len(df)):
    loc = df.iloc[i]["Location"]
    num = df.iloc[i]["Median"]
    d[loc] = num

# %%
print(d)
# Out:
# {'Luxembourg': 259899.0, 'Australia': 238072.0, 'Iceland': 231462.0, 'Belgium': 230548.0, 'Hong Kong': 173768.0, 'New Zealand': 171624.0, 'Denmark': 165622.0, 'Switzerland': 146733.0, 'Netherlands': 136105.0, 'France': 133559.0, 'United Kingdom': 131522.0, 'Canada': 125688.0, 'Japan': 122980.0, 'Italy': 118885.0, 'Norway': 117798.0, 'Spain': 105831.0, 'Ireland': 99028.0, 'Taiwan': 93044.0, 'Austria': 91833.0, 'Sweden': 89846.0, 'South Korea': 89671.0, 'Singapore': 86717.0, 'Malta': 84390.0, 'Qatar': 83680.0, 'Israel': 80315.0, 'United States': 79274.0, 'Finland': 73775.0, 'Slovenia': 67961.0, 'Germany': 65374.0, 'Portugal': 61306.0, 'Greece': 57595.0, 'Slovakia': 45853.0, 'Estonia': 38901.0, 'Cyprus': 35300.0, 'Croatia': 34945.0, 'Latvia': 33884.0, 'Montenegro': 30739.0, 'Lithuania': 29679.0, 'Kuwait': 28698.0, 'Mauritius': 27456.0, 'Seychelles': 24651.0, 'Hungary': 24126.0, 'China': 24067.0, 'Czech Republic': 23794.0, 'French Caribbe': 23740.0, 'Romania': 23675.0, 'Poland': 23550.0,
# ...

# %%
df = pd.read_csv(r"C:\Users\wmata\OneDrive\Documents\University\Year2\IML\IML.HUJI\challenge\country_code.csv")
df
# Out:
#             Country code
# 0       Afghanistan   AF
# 1           Albania   AL
# 2           Algeria   DZ
# 3    American Samoa   AS
# 4           Andorra   AD
# ..              ...  ...
# 244  Western Sahara   EH
# 245           Yemen   YE
# 246          Zambia   ZM
# 247        Zimbabwe   ZW
# 248   Åland Islands   AX
#
# [249 rows x 2 columns]

# %%
d_code = dict()
for i in range(len(df)):
    loc = df.iloc[i]["Country"]
    num = df.iloc[i]["code"]
    d_code[loc] = num

# %%
d_code
# Out:
# {'Afghanistan': 'AF',
#  'Albania': 'AL',
#  'Algeria': 'DZ',
#  'American Samoa': 'AS',
#  'Andorra': 'AD',
#  'Angola': 'AO',
#  'Anguilla': 'AI',
#  'Antarctica': 'AQ',
#  'Antigua and Barbuda': 'AG',
#  'Argentina': 'AR',
#  'Armenia': 'AM',
#  'Aruba': 'AW',
#  'Australia': 'AU',
#  'Austria': 'AT',
#  'Azerbaijan': 'AZ',
#  'Bahamas (the)': 'BS',
#  'Bahrain': 'BH',
#  'Bangladesh': 'BD',
#  'Barbados': 'BB',
#  'Belarus': 'BY',
#  'Belgium': 'BE',
#  'Belize': 'BZ',
#  'Benin': 'BJ',
#  'Bermuda': 'BM',
#  'Bhutan': 'BT',
#  'Bolivia (Plurinational State of)': 'BO',
#  'Bonaire, Sint Eustatius and Saba': 'BQ',
#  'Bosnia and Herzegovina': 'BA',
#  'Botswana': 'BW',
#  'Bouvet Island': 'BV',
#  'Brazil': 'BR',
#  'British Indian Ocean Territory (the)': 'IO',
#  'Brunei Darussalam': 'BN',
#  'Bulgaria': 'BG',
#  'Burkina Faso': 'BF',
#  'Burundi': 'BI',
#  'Cabo Verde': 'CV',
#  'Cambodia': 'KH',
#  'Cameroon': 'CM',
#  'Canada': 'CA',
#  'Cayman Islands (the)': 'KY',
# ...

# %%
new_dict = dict()

# %%
for country in d.keys():
    if country in d_code:
        new_dict[d_code[country]] = d[country]
    else:
        print(country)
# Out:
# Netherlands
# United Kingdom
# Taiwan
# South Korea
# United States
# Czech Republic
# French Caribbe
# United Arab Emirates
# Dutch Caribbe
# British West Indi
# Polynes
# Melanes
# Iran
# Moldova
# Bahamas
# Venezuela
# Russia
# Brunei
# Micronesia
# Vietnam
# Bolivia
# Philippines
# East Timor
# São Tomé and Príncipe
# Laos
# Comoros
# Tanzania
# Syria
# Gambia
# Congo
# Niger
# Sudan
# DR Congo
# Central African Republic

# %%
new_dict
# Out:
# {'LU': 259899.0,
#  'AU': 238072.0,
#  'IS': 231462.0,
#  'BE': 230548.0,
#  'HK': 173768.0,
#  'NZ': 171624.0,
#  'DK': 165622.0,
#  'CH': 146733.0,
#  'FR': 133559.0,
#  'CA': 125688.0,
#  'JP': 122980.0,
#  'IT': 118885.0,
#  'NO': 117798.0,
#  'ES': 105831.0,
#  'IE': 99028.0,
#  'AT': 91833.0,
#  'SE': 89846.0,
#  'SG': 86717.0,
#  'MT': 84390.0,
#  'QA': 83680.0,
#  'IL': 80315.0,
#  'FI': 73775.0,
#  'SI': 67961.0,
#  'DE': 65374.0,
#  'PT': 61306.0,
#  'GR': 57595.0,
#  'SK': 45853.0,
#  'EE': 38901.0,
#  'CY': 35300.0,
#  'HR': 34945.0,
#  'LV': 33884.0,
#  'ME': 30739.0,
#  'LT': 29679.0,
#  'KW': 28698.0,
#  'MU': 27456.0,
#  'SC': 24651.0,
#  'HU': 24126.0,
#  'CN': 24067.0,
#  'RO': 23675.0,
#  'PL': 23550.0,
#  'UY': 22088.0,
#  'BB': 21071.0,
#  'LB': 18159.0,
#  'CL': 17747.0,
#  'BG': 17403.0,
#  'TT': 15649.0,
#  'SA': 15495.0,
#  'AL': 15363.0,
#  'BA': 15283.0,
#  'RS': 14954.0,
#  'CR': 14662.0,
#  'BH': 14520.0,
#  'MX': 13752.0,
#  'PA': 13147.0,
# ...

# %%
df = pd.read_csv(r"C:\Users\wmata\OneDrive\Documents\University\Year2\IML\IML.HUJI\datasets\agoda_cancellation_train.csv")
df
# Out:
#               h_booking_id     booking_datetime         checkin_date  \
# 0     -9223194055642672935  2018-06-28 21:15:00  2018-07-09 00:00:00
# 1     -9222713784330706132  2018-08-10 22:31:00  2018-08-16 00:00:00
# 2     -9222411208325704942  2018-09-14 07:55:00  2018-09-14 00:00:00
# 3     -9222220845872895471  2018-06-25 07:33:00  2018-07-02 00:00:00
# 4     -9221127186162682116  2018-07-23 10:06:00  2018-08-09 00:00:00
# ...                    ...                  ...                  ...
# 58654  9221958224902563533  2018-07-18 22:07:00  2018-08-04 00:00:00
# 58655  9222015611933681753  2018-09-05 12:07:00  2018-09-06 00:00:00
# 58656  9222651806661094957  2018-06-08 23:23:00  2018-08-09 00:00:00
# 58657  9223221736086584899  2018-09-02 08:18:00  2018-09-10 00:00:00
# 58658  9223338323510018406  2018-07-07 10:46:00  2018-07-12 00:00:00
#
#              checkout_date  hotel_id hotel_country_code      hotel_live_date  \
# ...
